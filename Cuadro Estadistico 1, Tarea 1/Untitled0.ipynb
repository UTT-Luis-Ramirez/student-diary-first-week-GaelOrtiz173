# %% [markdown]
# #Ni idea xde
#
# ---

# %%
import pandas as pd

data = pd.read_csv("SoftwareProject_DataSet.csv")

# %% [markdown]
# ##Verificacion del contenido del DataSet
#
# ---

# %%
data.head()
# Out:
#                      Proyecto    Módulo     Desarrollador  Líneas de código  \
# 0   Smith, Torres and Flowers      long     Patricia Ford              4227
# 1             Jordan and Sons      lose    Melissa Briggs              6124
# 2  Madden, Jackson and Keller  thousand  Alexander Spence               588
# 3                 Evans Group     table    Michael Porter              5796
# 4                 Pearson LLC     light    Andrew Gregory              3019
#
#    Número de bugs  Tiempo de desarrollo (horas)  Costo (USD)  \
# 0              39                           375        84053
# 1              37                           132        82167
# 2              30                           441        75204
# 3              17                            87        32147
# 4              11                           263        44998
#
#    Satisfacción del cliente  Antigüedad del desarrollador (años)  \
# 0                         1                                   10
# 1                         5                                    9
# 2                         3                                    7
# 3                         1                                    1
# 4                         2                                    5
#
#   Idioma de programación Plataforma   Tipo de proyecto Fase del proyecto  \
# 0                   Java     Mobile        Application        Deployment
# 1                 Kotlin     Mobile  Management System           Testing
# 2             Javascript     Mobile        Application        Deployment
# 3                 Kotlin     Mobile        Application            Design
# 4                 Python    Desktop           Web site       Development
#
#    Tamaño del equipo                Tecnologías
# 0                  7  professor, evidence, down
# 1                 10          clear, rich, tend
# 2                 10       process, cut, debate
# 3                  1    bank, management, those
# 4                  3         you, visit, camera

# %% [markdown]
# ##Obtener el tamaño de la poblacion
#
# ---

# %%
population_size = len(data)
print("The Poupulation size is over: ", population_size)
# Out:
# The Poupulation size is over:  10000

# %% [markdown]
# ##Creacion de muestra aleatoria simple de 50 registros
#
# ---

# %%
sample_size = 50
simple_sample = data.sample(n=sample_size)

# %% [markdown]
# ##Revision de creacion de la muestra
#
# ---

# %%
display(simple_sample)
# Out:
#                             Proyecto      Módulo        Desarrollador  \
# 7581                    Murphy Group      notice      Jennifer Obrien
# 411                      Vazquez PLC      friend      Gabrielle Brown
# 3175                        Webb Inc      travel        Morgan Martin
# 9379        Hughes, Day and Hamilton        room       Emily Phillips
# 5950        Foster, Simpson and Ball         gas          Amy Russell
# 297                    Martin-Mccall       under      Jennifer Nguyen
# 9786       Dawson, Wright and Bailey       laugh          Paige Mills
# 5776                 Harris and Sons       serve        Hector Miller
# 6938                       Lee Group      strong          Hannah King
# 473                    King and Sons      nature       Jonathan Gomez
# 7539        Pierce, Mason and Foster          he       Thomas Ramirez
# 871                     Marsh-Harris    response          Ralph Gomez
# 4941                       Woods Inc    economic         Jordan Payne
# 4844                    Moore-Warren       above         Chelsea Cole
# 3533                      Miller Inc        kind       Joseph Johnson
# 162                    Wright-Walter    language         Sarah Hunter
# 5951                     Sanders Inc      travel          Erika Clark
# 5650                 Solomon-Schmidt        able      Brittany Turner
# 2923     Taylor, Wilkerson and Smith       truth    Katherine Mccarty
# 1175   Santiago, Gardner and Perkins       write       Jessica Bryant
# 75                      Ramsey-Moore        hope       Jose Rasmussen
# 8684                 Garrett-Schmidt    research           Larry Rose
# 9285    Davidson, Hamilton and Green     prevent      Savannah Rogers
# 5022                   Wilkinson Ltd       thing         Thomas Lopez
# 8309                   Fisher-Chavez   including       Michael Bryant
# 8635                     Lopez-Smith      inside        Heather Smith
# 746                      Hammond Inc     morning          Steven Diaz
# 5826       Holmes, Bell and Robinson     officer         Donald Brown
# 5745          Garrett, Walsh and Ali          be     Elizabeth Kelley
# 6623      Armstrong, Ford and Bailey     without           April Cole
# 2712    Sampson, Garcia and Phillips   challenge      Lori Cunningham
# 827     Anderson, Morgan and Stanley         win  Kimberly Williamson
# 6332                       Sims-Ross        bill         Colin Barnes
# 6553     Ferguson, Kennedy and Gross   treatment        Monica Martin
# 8802  Patterson, Beck and Fitzgerald      moment           Debra Rice
# 1724                     Mcbride LLC        card       Michael Graham
# 3584                   Henderson Inc         she       Kevin Anderson
# 9549               Roberts-Rodriguez        fine     Joseph Macdonald
# 433                     Pineda Group      dinner       Richard Waller
# 9400         Hodges, Taylor and Love       seven       Katrina Guzman
# 6102                    Williams PLC        join      Jessica Harrell
# 8026                    Mcdowell Ltd    approach         Heather Choi
# 7618                     King-Galvan      market         Shannon Hall
# 8267   Evans, Williamson and Jenkins        fact      William Wilkins
# 2569       Smith, Marshall and Mason   recognize         Peggy Garcia
# 9879                       Weber PLC       alone        Andrew Wright
# 1375       Hamilton, Soto and Duarte        fast        Richard Boyle
# 4111           Wong, Gray and Norman   according        Joseph Garcia
# 3122                     Fleming Inc  especially       Melissa Flores
# 5540                 Thomas-Anderson        foot     Cynthia Mcknight
#
#       Líneas de código  Número de bugs  Tiempo de desarrollo (horas)  \
# 7581              9689              35                           450
# 411               9325               1                            53
# 3175              2266              45                           247
# 9379              8604              50                           457
# 5950              9446              20                           462
# 297               3224              48                           137
# 9786              1282              30                           473
# 5776              2940              37                           460
# 6938              2608              28                            56
# 473               4532              38                           209
# 7539              8398              18                           481
# 871               7863              50                           270
# 4941              8645              23                           288
# 4844              6114              21                           419
# 3533              7882              48                           178
# 162               9484              32                           246
# 5951              5300              47                           402
# 5650              3065              37                           241
# 2923              3470              23                           439
# 1175              7321              25                           301
# 75                1489              19                           289
# 8684              4715              12                           135
# 9285              3609              38                           101
# 5022              4861              48                           112
# 8309              3407              42                           351
# 8635              8815               0                           486
# 746               9766              30                            99
# 5826               267              26                            86
# 5745               433              16                           364
# 6623              3420              44                            94
# 2712              7232              39                           303
# 827               7929              23                           499
# 6332              8301              13                           354
# 6553               858              21                           139
# 8802              8353              44                           133
# 1724              2649              24                           241
# 3584              7741              48                           405
# 9549              3339               5                           190
# 433               1778              33                           214
# 9400              6894              11                           290
# 6102              7860              40                            40
# 8026              4664              35                           205
# 7618              2265               7                           438
# 8267              2982              14                           451
# 2569              8693              35                           387
# 9879              7348               7                            19
# 1375               895              33                           376
# 4111              9279              31                           372
# 3122              8065              40                           462
# 5540              2342               8                           496
#
#       Costo (USD)  Satisfacción del cliente  \
# 7581        94351                         4
# 411         71053                         5
# 3175        51147                         4
# 9379        75056                         1
# 5950        79356                         5
# 297         12465                         5
# 9786        12396                         2
# 5776        59815                         4
# 6938        23486                         2
# 473          7272                         4
# 7539        92348                         5
# 871         78119                         3
# 4941        31017                         1
# 4844        32763                         1
# 3533        47292                         1
# 162         18173                         4
# 5951        11857                         1
# 5650         5671                         1
# 2923        81466                         5
# 1175        85454                         1
# 75          71323                         2
# 8684        27523                         4
# 9285        16521                         3
# 5022        10719                         3
# 8309        19073                         5
# 8635        96492                         3
# 746         43588                         3
# 5826        78170                         3
# 5745        83160                         2
# 6623        56396                         4
# 2712        32850                         1
# 827         44225                         1
# 6332        80868                         2
# 6553        44033                         1
# 8802        26268                         2
# 1724        41924                         4
# 3584        16424                         3
# 9549        82077                         4
# 433         85551                         4
# 9400        36631                         4
# 6102        95544                         2
# 8026        77533                         5
# 7618        46634                         5
# 8267        47317                         1
# 2569        64865                         4
# 9879        85900                         5
# 1375        48437                         3
# 4111        48935                         5
# 3122        22269                         1
# 5540        69533                         5
#
#       Antigüedad del desarrollador (años) Idioma de programación Plataforma  \
# 7581                                   13                 Python    Desktop
# 411                                    11             Javascript        Web
# 3175                                    7                 Python    Desktop
# 9379                                    3                 Python     Mobile
# 5950                                    3                   Java        Web
# 297                                    12                 Kotlin     Mobile
# 9786                                    3                 Python        Web
# 5776                                    5                   Java     Mobile
# 6938                                    4                   Java     Mobile
# 473                                     9                 Kotlin     Mobile
# 7539                                    8                 Python    Desktop
# 871                                     1                 Kotlin        Web
# 4941                                    8                 Kotlin     Mobile
# 4844                                    9                 Kotlin        Web
# 3533                                   12                 Python    Desktop
# 162                                    10                 Kotlin     Mobile
# 5951                                    9                 Python    Desktop
# 5650                                   15                 Python     Mobile
# 2923                                   14                 Python     Mobile
# 1175                                    6                   Java    Desktop
# 75                                      2                 Kotlin     Mobile
# 8684                                    2                   Java    Desktop
# 9285                                   11                   Java    Desktop
# 5022                                    8             Javascript    Desktop
# 8309                                    4                   Java    Desktop
# 8635                                   14                 Kotlin        Web
# 746                                    15                 Python     Mobile
# 5826                                    9                 Python    Desktop
# 5745                                    6                 Python    Desktop
# 6623                                   10             Javascript        Web
# 2712                                   14                 Kotlin     Mobile
# 827                                     7                 Kotlin     Mobile
# 6332                                   14                 Kotlin    Desktop
# 6553                                    2             Javascript        Web
# 8802                                   10             Javascript    Desktop
# 1724                                   13                   Java        Web
# 3584                                   12                   Java        Web
# 9549                                    7                   Java     Mobile
# 433                                    12                   Java    Desktop
# 9400                                    6                   Java     Mobile
# 6102                                   11                 Kotlin    Desktop
# 8026                                    8             Javascript     Mobile
# 7618                                    4                 Python     Mobile
# 8267                                    2             Javascript        Web
# 2569                                   12                   Java     Mobile
# 9879                                   12                 Kotlin     Mobile
# 1375                                    9                   Java    Desktop
# 4111                                   10             Javascript    Desktop
# 3122                                    6             Javascript     Mobile
# 5540                                   15                   Java    Desktop
#
#        Tipo de proyecto Fase del proyecto  Tamaño del equipo  \
# 7581           Web site            Design                  8
# 411   Management System            Design                  6
# 3175           Web site       Development                  2
# 9379        Application           Testing                 10
# 5950           Web site       Development                  5
# 297            Web site           Testing                  3
# 9786           Web site       Development                  4
# 5776  Management System           Testing                  7
# 6938        Application            Design                  6
# 473            Web site           Testing                  9
# 7539           Web site           Testing                  3
# 871         Application        Deployment                  8
# 4941           Web site           Testing                  9
# 4844           Web site            Design                  2
# 3533           Web site       Development                  5
# 162            Web site            Design                  2
# 5951        Application        Deployment                 10
# 5650  Management System       Development                  2
# 2923  Management System            Design                  3
# 1175        Application           Testing                  5
# 75          Application            Design                  6
# 8684           Web site        Deployment                 10
# 9285        Application       Development                  7
# 5022  Management System           Testing                  2
# 8309        Application        Deployment                 10
# 8635        Application            Design                  8
# 746            Web site           Testing                  3
# 5826        Application       Development                 10
# 5745  Management System       Development                  1
# 6623        Application       Development                  3
# 2712        Application           Testing                 10
# 827         Application        Deployment                  8
# 6332           Web site       Development                  2
# 6553        Application       Development                  2
# 8802        Application            Design                  3
# 1724        Application            Design                 10
# 3584           Web site            Design                  3
# 9549           Web site           Testing                  5
# 433         Application        Deployment                  5
# 9400           Web site        Deployment                  7
# 6102  Management System            Design                  9
# 8026  Management System           Testing                  9
# 7618        Application            Design                  7
# 8267  Management System       Development                  1
# 2569  Management System        Deployment                  6
# 9879  Management System        Deployment                  2
# 1375  Management System        Deployment                  2
# 4111           Web site       Development                  1
# 3122  Management System           Testing                  3
# 5540  Management System            Design                  4
#
#                       Tecnologías
# 7581           listen, join, part
# 411               worry, us, here
# 3175            yes, occur, share
# 9379            late, summer, but
# 5950        simply, me, important
# 297              far, think, cost
# 9786     financial, role, explain
# 5776           add, popular, drop
# 6938     system, candidate, staff
# 473       enough, event, daughter
# 7539      property, better, south
# 871       coach, benefit, tonight
# 4941     standard, ground, always
# 4844      wall, human, successful
# 3533              out, raise, lay
# 162          later, happy, manage
# 5951          mean, firm, article
# 5650  technology, police, usually
# 2923        two, challenge, small
# 1175     happy, military, network
# 75     another, billion, customer
# 8684        these, other, project
# 9285            late, my, example
# 5022            pull, long, issue
# 8309         now, true, condition
# 8635        sister, choice, third
# 746   market, particularly, still
# 5826           happy, adult, four
# 5745          show, though, whose
# 6623             two, other, mind
# 2712       thousand, run, without
# 827             detail, blue, bit
# 6332     figure, senior, personal
# 6553          fish, boy, physical
# 8802             will, during, as
# 1724               card, us, mind
# 3584     dinner, popular, several
# 9549          without, thus, both
# 433           hotel, person, vote
# 9400         feeling, ever, thank
# 6102     knowledge, teach, itself
# 8026     serious, thousand, start
# 7618        order, rate, discover
# 8267           threat, song, base
# 2569              hot, book, want
# 9879    happen, suggest, positive
# 1375         example, carry, take
# 4111           various, blue, out
# 3122       surface, drive, nation
# 5540          can, west, physical

# %% [markdown]
# ##Demostrar el tamaño de la muestra
#
# ---

# %%
sample_size = len(simple_sample)
print("The Sample size is over: ", sample_size)
# Out:
# The Sample size is over:  50

# %% [markdown]
# ##Descripcion estadistica de la muestra (Ejemplo)
#
# ---

# %%
sample_description = simple_sample[['Costo (USD)','Tiempo de desarrollo (horas)']].describe()
print("Descripcion estadistica de la muestra: ")
display(sample_description)
# Out:
# Descripcion estadistica de la muestra:
#         Costo (USD)  Tiempo de desarrollo (horas)
# count     50.000000                      50.00000
# mean   51426.800000                     288.00000
# std    28194.287184                     147.23118
# min     5671.000000                      19.00000
# 25%    26581.750000                     148.75000
# 50%    47877.000000                     289.50000
# 75%    78157.250000                     433.25000
# max    96492.000000                     499.00000

# %% [markdown]
# #Muestreo aleatorio sistematico
#
# ---

# %% [markdown]
# ##Seleccion sistematica de una muestra
#
# ---

# %% [markdown]
# ##Definir el intervalo K (tamaño poblacion / muestra deseada)
#
# ---

# %%
sample_size = 80
k_interval = population_size // sample_size

# %% [markdown]
# ##Seleccion de muestra sistematica
#
# ---

# %%
systematic_sample = data.iloc[::k_interval]

# %% [markdown]
# ##Verificacion de la muestra
#
# ---

# %%
print("Muestreo obtenida a traves de muestreo aleatorio sistematic")
display(systematic_sample)
# Out:
# Muestreo obtenida a traves de muestreo aleatorio sistematic
#                            Proyecto      Módulo    Desarrollador  \
# 0         Smith, Torres and Flowers        long    Patricia Ford
# 125        Parker, Parrish and Tate      office      Craig Wolfe
# 250        Thomas, Yang and Jenkins      series       Tina Rivas
# 375                       Olson LLC        both       Susan Todd
# 500   Dominguez, Vasquez and Miller      really  Taylor Robinson
# ...                             ...         ...              ...
# 9375                     Flores PLC        site        Jay Brown
# 9500  Adams, Simmons and Richardson  understand  Richard Johnson
# 9625                     Farley Ltd      series    Frank Merritt
# 9750              Vazquez-Hendricks     forward   Kristen Conrad
# 9875                Taylor and Sons    majority       Matthew Yu
#
#       Líneas de código  Número de bugs  Tiempo de desarrollo (horas)  \
# 0                 4227              39                           375
# 125               9569              12                           375
# 250               6157              47                           309
# 375                286              33                           231
# 500                693              36                           304
# ...                ...             ...                           ...
# 9375              5816               6                           487
# 9500              6457              38                           334
# 9625              6152               3                           292
# 9750              7886              16                           179
# 9875              4639              20                           335
#
#       Costo (USD)  Satisfacción del cliente  \
# 0           84053                         1
# 125         92730                         4
# 250         49045                         5
# 375         46265                         1
# 500         12845                         1
# ...           ...                       ...
# 9375        26443                         2
# 9500        76598                         4
# 9625        11181                         1
# 9750        22999                         2
# 9875        93315                         5
#
#       Antigüedad del desarrollador (años) Idioma de programación Plataforma  \
# 0                                      10                   Java     Mobile
# 125                                     3             Javascript        Web
# 250                                    10                 Kotlin     Mobile
# 375                                     2                   Java        Web
# 500                                    12                 Python        Web
# ...                                   ...                    ...        ...
# 9375                                    2                 Kotlin        Web
# 9500                                    3                 Python    Desktop
# 9625                                    1                 Python        Web
# 9750                                   10                 Kotlin        Web
# 9875                                    4                   Java     Mobile
#
#        Tipo de proyecto Fase del proyecto  Tamaño del equipo  \
# 0           Application        Deployment                  7
# 125   Management System       Development                  4
# 250         Application        Deployment                  9
# 375         Application        Deployment                 10
# 500         Application       Development                  2
# ...                 ...               ...                ...
# 9375        Application            Design                  6
# 9500  Management System       Development                  2
# 9625  Management System           Testing                  9
# 9750           Web site            Design                  7
# 9875           Web site       Development                  8
#
#                       Tecnologías
# 0       professor, evidence, down
# 125              idea, arm, place
# 250          any, strong, clearly
# 375          center, mouth, share
# 500          assume, after, there
# ...                           ...
# 9375            go, early, course
# 9500     soon, operation, outside
# 9625    anything, ahead, painting
# 9750        either, fast, general
# 9875  represent, explain, himself
#
# [80 rows x 15 columns]

# %% [markdown]
# #Analisis de subpoblacion
#
# ---

# %% [markdown]
# ##Dividir la poblacion por tipo de proyecto
#
# ---

# %%
grouped_by_project_type = data.groupby('Tipo de proyecto')

# %% [markdown]
# ##Calcular el promedio de lineas de codigo y bugs para cada subpoblacion
#
# ---

# %%
group_analysis = grouped_by_project_type[['Líneas de código', 'Número de bugs', 'Costo (USD)']].mean()
print("Analisis de subpoblacion: ")
display(group_analysis)
# Out:
# Analisis de subpoblacion:
#                    Líneas de código  Número de bugs   Costo (USD)
# Tipo de proyecto
# Application             5010.898008       25.308058  51179.995540
# Management System       5120.102603       25.029096  50514.636753
# Web site                5045.105872       24.800712  50707.962040
