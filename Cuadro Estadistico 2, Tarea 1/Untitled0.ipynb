# %% [markdown]
# #Ni idea xde
#
# ---

# %%
import pandas as pd

data = pd.read_csv("SoftwareProject_DataSet.csv")

# %% [markdown]
# ##Verificacion del contenido del DataSet
#
# ---

# %%
data.head()
# Out:
#                      Proyecto    Módulo     Desarrollador  Líneas de código  \
# 0   Smith, Torres and Flowers      long     Patricia Ford              4227
# 1             Jordan and Sons      lose    Melissa Briggs              6124
# 2  Madden, Jackson and Keller  thousand  Alexander Spence               588
# 3                 Evans Group     table    Michael Porter              5796
# 4                 Pearson LLC     light    Andrew Gregory              3019
#
#    Número de bugs  Tiempo de desarrollo (horas)  Costo (USD)  \
# 0              39                           375        84053
# 1              37                           132        82167
# 2              30                           441        75204
# 3              17                            87        32147
# 4              11                           263        44998
#
#    Satisfacción del cliente  Antigüedad del desarrollador (años)  \
# 0                         1                                   10
# 1                         5                                    9
# 2                         3                                    7
# 3                         1                                    1
# 4                         2                                    5
#
#   Idioma de programación Plataforma   Tipo de proyecto Fase del proyecto  \
# 0                   Java     Mobile        Application        Deployment
# 1                 Kotlin     Mobile  Management System           Testing
# 2             Javascript     Mobile        Application        Deployment
# 3                 Kotlin     Mobile        Application            Design
# 4                 Python    Desktop           Web site       Development
#
#    Tamaño del equipo                Tecnologías
# 0                  7  professor, evidence, down
# 1                 10          clear, rich, tend
# 2                 10       process, cut, debate
# 3                  1    bank, management, those
# 4                  3         you, visit, camera

# %% [markdown]
# ##Obtener el tamaño de la poblacion
#
# ---

# %%
population_size = len(data)
print("The Poupulation size is over: ", population_size)
# Out:
# The Poupulation size is over:  10000

# %% [markdown]
# ##Creacion de muestra aleatoria simple de 50 registros
#
# ---

# %%
sample_size = 50
simple_sample = data.sample(n=sample_size)

# %% [markdown]
# ##Revision de creacion de la muestra
#
# ---

# %%
display(simple_sample)
# Out:
#                           Proyecto      Módulo       Desarrollador  \
# 1058                    Mays-Jones  government         Alexis Hale
# 7181                Lindsey-Harris         old        David Jordan
# 7216                 Prince-Hayden         red     Katherine Woods
# 5514  Garcia, Collins and Trujillo    Congress      Maria Anderson
# 8767             Perkins-Carpenter       house        Thomas Price
# 5710                Anderson-Smith         top      Brittany Adams
# 4941                     Woods Inc    economic        Jordan Payne
# 862                  Mason-Johnson   structure         Debra Nolan
# 2690                    Carter Ltd       maybe          Laura Chan
# 6511     Carrillo, Levy and Dawson    anything   Christopher Lopez
# 2596         Coleman, Lee and Hall      during           Emma Mann
# 7041                   Ford-Jordan        into       Shaun Johnson
# 3560       Mueller, Fox and Austin      assume         Lisa Torres
# 157                Fuentes-Simmons     success        James Little
# 8303        Moran, Lawson and Rice        look      Nicholas White
# 3044        Hardy, Weber and Smith      decide          Mary Casey
# 1113                George-Coleman         now    Christina Thomas
# 3013    Strickland, Nguyen and Kim        move     Valerie Delgado
# 5902    King, Campbell and Johnson     require      Rebecca Ramsey
# 7001                  Arnold-Parks      finish      Tabitha Moreno
# 1490     Walker, Wright and Sutton        skin    Michelle Ramirez
# 7274                      Lamb LLC    Democrat     Brandon Sherman
# 1134    Jones, Anthony and Mullins        make      Johnathan Lane
# 2204                   Sanchez Ltd      before      Nicole Jimenez
# 1488    Harris, Hardy and Delacruz       happy   Elizabeth Edwards
# 5963                Collins-Mendez        draw        Taylor Brady
# 2227       Perry, Hansen and Roman       music          Gary White
# 3320                     Gomez PLC       young       Ryan Mcdonald
# 9984                 Hudson-Miller        plan          Stacey Kim
# 5477             Phillips-Sullivan        from          Amy Becker
# 6451                      Rios-Roy      manage         Tonya Hardy
# 5560                Reynolds Group        than    Darren Blackwell
# 4238                Smith and Sons        week       Alexis Warner
# 396     Moreno, Williams and Duran    majority    Jessica Holloway
# 1302               Rivera-Roberson        land     Lindsay Morales
# 6784               Hodges-Mcdonald        rule         Kevin Lewis
# 95      Collins, Burns and Goodman      decide       Roberta Jones
# 9562               Dalton-Bautista        team        Sarah Morris
# 8388        Smith, Jones and Davis      report  Christopher Cooper
# 7598                    Harvey Ltd   difficult        John Jackson
# 9556                    Miller PLC         can         Paul Barton
# 9695                  Bowers Group     explain         Peter Brown
# 8057                  Reed-Mahoney     however        Emily Butler
# 5402                   Collins Ltd         let        Joshua Black
# 4502          Harvey, Tran and Day      modern       Gina Webb PhD
# 3509    Powell, Evans and Espinoza        pass        Toni Johnson
# 1160                      King PLC         oil        Sandra Henry
# 5852                Carroll-Wilson       young   Mallory Schneider
# 6544                    Little PLC     reality     Suzanne Johnson
# 6462                     White Ltd     product         Lisa Larsen
#
#       Líneas de código  Número de bugs  Tiempo de desarrollo (horas)  \
# 1058              1075              45                           159
# 7181              9493              21                           304
# 7216              2465              13                            39
# 5514              3601               1                           320
# 8767               850               4                            87
# 5710              8355              21                           429
# 4941              8645              23                           288
# 862               3439              24                            19
# 2690               949              12                            71
# 6511              1448              49                           136
# 2596              8517              20                           147
# 7041               395              49                           119
# 3560              7892               8                           411
# 157               8942              37                           244
# 8303              3832              41                           484
# 3044              9961              37                            11
# 1113              6332              33                           201
# 3013              6626              19                           202
# 5902              2167               7                           150
# 7001               492              40                           495
# 1490              7658              25                           318
# 7274              6815              46                           276
# 1134              5415              46                           279
# 2204              9990              23                           279
# 1488              3587              29                           294
# 5963              6265              17                           454
# 2227              8239              39                           315
# 3320              2848              21                           343
# 9984              2691              21                           120
# 5477              9562               6                           352
# 6451              5744              27                           483
# 5560               191               6                           453
# 4238               873              42                           445
# 396               2794              40                            90
# 1302              2591              18                           148
# 6784              7875              11                           402
# 95                 261              49                           416
# 9562              7203              45                           127
# 8388              9185              34                           165
# 7598              1315              10                           357
# 9556              6082              45                            52
# 9695              1639              46                           175
# 8057              8832              44                           393
# 5402              5865              39                           283
# 4502              5251              41                           446
# 3509              9301               1                           247
# 1160              8060              19                            58
# 5852              8934              44                           376
# 6544              1416               1                           469
# 6462              1093              47                           123
#
#       Costo (USD)  Satisfacción del cliente  \
# 1058         2500                         2
# 7181        50590                         5
# 7216        52909                         2
# 5514        80961                         1
# 8767        52173                         4
# 5710        91856                         1
# 4941        31017                         1
# 862         23655                         1
# 2690        17976                         2
# 6511        80109                         3
# 2596        14624                         1
# 7041        93636                         5
# 3560        46144                         5
# 157          1884                         4
# 8303        89401                         4
# 3044        41162                         1
# 1113         7553                         4
# 3013        48736                         1
# 5902        39796                         1
# 7001        76672                         5
# 1490        33223                         4
# 7274        30172                         2
# 1134         4217                         4
# 2204         5797                         1
# 1488        52790                         4
# 5963        25544                         3
# 2227        50266                         1
# 3320        71963                         4
# 9984        61416                         5
# 5477        40016                         5
# 6451        23807                         1
# 5560        35232                         1
# 4238         6821                         1
# 396         54007                         2
# 1302        88748                         1
# 6784        70878                         4
# 95          94586                         5
# 9562        65818                         2
# 8388        56127                         5
# 7598        18419                         2
# 9556        20642                         5
# 9695        54340                         1
# 8057        40386                         1
# 5402        63214                         3
# 4502        52105                         4
# 3509        35637                         4
# 1160        10800                         4
# 5852        81125                         3
# 6544        37785                         5
# 6462        75620                         1
#
#       Antigüedad del desarrollador (años) Idioma de programación Plataforma  \
# 1058                                   15                   Java        Web
# 7181                                    9                 Kotlin        Web
# 7216                                    6                 Python        Web
# 5514                                   10             Javascript        Web
# 8767                                   14                 Kotlin    Desktop
# 5710                                    5             Javascript     Mobile
# 4941                                    8                 Kotlin     Mobile
# 862                                    14                   Java     Mobile
# 2690                                    2                   Java    Desktop
# 6511                                   13                 Kotlin     Mobile
# 2596                                   12                 Kotlin        Web
# 7041                                    4                   Java    Desktop
# 3560                                   14             Javascript    Desktop
# 157                                     9                 Python    Desktop
# 8303                                    1                   Java        Web
# 3044                                    5             Javascript        Web
# 1113                                    2                 Kotlin    Desktop
# 3013                                   15                 Kotlin     Mobile
# 5902                                    4                   Java    Desktop
# 7001                                   10                 Kotlin     Mobile
# 1490                                    2             Javascript        Web
# 7274                                   12             Javascript        Web
# 1134                                    6             Javascript     Mobile
# 2204                                   15                   Java        Web
# 1488                                   12                   Java    Desktop
# 5963                                    2                   Java     Mobile
# 2227                                    1             Javascript     Mobile
# 3320                                    6                 Kotlin     Mobile
# 9984                                    9             Javascript    Desktop
# 5477                                    9                 Python        Web
# 6451                                    3                 Python        Web
# 5560                                   15                   Java        Web
# 4238                                    4             Javascript        Web
# 396                                    13                   Java    Desktop
# 1302                                    6                   Java        Web
# 6784                                    5                 Kotlin    Desktop
# 95                                      4                 Python        Web
# 9562                                   12                 Kotlin     Mobile
# 8388                                    2             Javascript    Desktop
# 7598                                    2             Javascript     Mobile
# 9556                                   14             Javascript        Web
# 9695                                   14                   Java     Mobile
# 8057                                   13                 Python     Mobile
# 5402                                    4                 Kotlin     Mobile
# 4502                                    6                 Kotlin    Desktop
# 3509                                    9             Javascript     Mobile
# 1160                                    3                 Python     Mobile
# 5852                                    9                   Java     Mobile
# 6544                                    9                   Java     Mobile
# 6462                                    5             Javascript    Desktop
#
#        Tipo de proyecto Fase del proyecto  Tamaño del equipo  \
# 1058        Application       Development                  1
# 7181  Management System        Deployment                  5
# 7216        Application            Design                  7
# 5514        Application           Testing                  9
# 8767  Management System           Testing                  1
# 5710           Web site        Deployment                  7
# 4941           Web site           Testing                  9
# 862            Web site        Deployment                  5
# 2690        Application           Testing                  6
# 6511  Management System            Design                  1
# 2596  Management System            Design                  9
# 7041        Application        Deployment                 10
# 3560           Web site            Design                  2
# 157            Web site        Deployment                  7
# 8303           Web site        Deployment                  1
# 3044        Application        Deployment                  9
# 1113  Management System        Deployment                  6
# 3013        Application       Development                  7
# 5902           Web site           Testing                  6
# 7001        Application            Design                  7
# 1490  Management System       Development                  2
# 7274  Management System           Testing                  9
# 1134           Web site            Design                  6
# 2204        Application       Development                  9
# 1488  Management System       Development                  1
# 5963        Application            Design                  4
# 2227  Management System            Design                  5
# 3320           Web site           Testing                  2
# 9984        Application        Deployment                  6
# 5477  Management System           Testing                  3
# 6451           Web site        Deployment                  7
# 5560           Web site           Testing                  2
# 4238        Application           Testing                  5
# 396         Application        Deployment                  2
# 1302  Management System            Design                  4
# 6784           Web site           Testing                  2
# 95          Application            Design                  5
# 9562           Web site       Development                  4
# 8388  Management System            Design                  2
# 7598           Web site            Design                  8
# 9556           Web site       Development                  2
# 9695  Management System       Development                  3
# 8057           Web site       Development                  5
# 5402        Application           Testing                  1
# 4502           Web site            Design                  7
# 3509        Application        Deployment                  7
# 1160  Management System       Development                  5
# 5852           Web site            Design                  9
# 6544  Management System        Deployment                  3
# 6462           Web site       Development                  9
#
#                              Tecnologías
# 1058         industry, ability, question
# 7181                  sing, threat, send
# 7216                  top, quality, five
# 5514                thus, anyone, police
# 8767            outside, indeed, measure
# 5710                 military, bag, ball
# 4941            standard, ground, always
# 862                   sort, front, visit
# 2690           artist, behavior, someone
# 6511                  win, while, beyond
# 2596                  wish, feel, manage
# 7041          town, decision, population
# 3560             every, evidence, writer
# 157                   serve, style, just
# 8303            blood, development, once
# 3044              newspaper, whole, page
# 1113               different, watch, key
# 3013                along, prevent, sing
# 5902  responsibility, specific, resource
# 7001             south, health, property
# 1490             mission, miss, evidence
# 7274           later, before, collection
# 1134    necessary, significant, attorney
# 2204                 here, than, provide
# 1488                   team, deal, smile
# 5963           outside, partner, clearly
# 2227               single, machine, talk
# 3320                  blue, family, will
# 9984                         be, size, a
# 5477                  life, radio, movie
# 6451                fact, often, reality
# 5560                 raise, effort, back
# 4238                  arm, unit, partner
# 396               always, yeah, activity
# 1302               hot, against, forward
# 6784                    add, just, crime
# 95                 set, house, beautiful
# 9562          arm, understand, treatment
# 8388              with, actually, little
# 7598                month, audience, add
# 9556                    red, major, hold
# 9695           experience, bank, machine
# 8057              yard, reality, culture
# 5402          shake, American, including
# 4502                 miss, simple, heavy
# 3509                 dark, beyond, could
# 1160               nothing, poor, pretty
# 5852             watch, goal, discussion
# 6544                    phone, some, run
# 6462                 them, student, than

# %% [markdown]
# ##Demostrar el tamaño de la muestra
#
# ---

# %%
sample_size = len(simple_sample)
print("The Sample size is over: ", sample_size)
# Out:
# The Sample size is over:  50

# %% [markdown]
# ##Descripcion estadistica de la muestra (Ejemplo)
#
# ---

# %%
sample_description = simple_sample[['Idioma de programación','Satisfacción del cliente']].describe()
print("Descripcion estadistica de la muestra: ")
display(sample_description)
# Out:
# Descripcion estadistica de la muestra:
#        Satisfacción del cliente
# count                 50.000000
# mean                   2.820000
# std                    1.599617
# min                    1.000000
# 25%                    1.000000
# 50%                    3.000000
# 75%                    4.000000
# max                    5.000000

# %% [markdown]
# #Muestreo aleatorio sistematico
#
# ---

# %% [markdown]
# ##Seleccion sistematica de una muestra
#
# ---

# %% [markdown]
# ##Definir el intervalo K (tamaño poblacion / muestra deseada)
#
# ---

# %%
sample_size = 80
k_interval = population_size // sample_size

# %% [markdown]
# ##Seleccion de muestra sistematica
#
# ---

# %%
systematic_sample = data.iloc[::k_interval]

# %% [markdown]
# ##Verificacion de la muestra
#
# ---

# %%
print("Muestreo obtenida a traves de muestreo aleatorio sistematic")
display(systematic_sample)
# Out:
# Muestreo obtenida a traves de muestreo aleatorio sistematic
#                            Proyecto      Módulo    Desarrollador  \
# 0         Smith, Torres and Flowers        long    Patricia Ford
# 125        Parker, Parrish and Tate      office      Craig Wolfe
# 250        Thomas, Yang and Jenkins      series       Tina Rivas
# 375                       Olson LLC        both       Susan Todd
# 500   Dominguez, Vasquez and Miller      really  Taylor Robinson
# ...                             ...         ...              ...
# 9375                     Flores PLC        site        Jay Brown
# 9500  Adams, Simmons and Richardson  understand  Richard Johnson
# 9625                     Farley Ltd      series    Frank Merritt
# 9750              Vazquez-Hendricks     forward   Kristen Conrad
# 9875                Taylor and Sons    majority       Matthew Yu
#
#       Líneas de código  Número de bugs  Tiempo de desarrollo (horas)  \
# 0                 4227              39                           375
# 125               9569              12                           375
# 250               6157              47                           309
# 375                286              33                           231
# 500                693              36                           304
# ...                ...             ...                           ...
# 9375              5816               6                           487
# 9500              6457              38                           334
# 9625              6152               3                           292
# 9750              7886              16                           179
# 9875              4639              20                           335
#
#       Costo (USD)  Satisfacción del cliente  \
# 0           84053                         1
# 125         92730                         4
# 250         49045                         5
# 375         46265                         1
# 500         12845                         1
# ...           ...                       ...
# 9375        26443                         2
# 9500        76598                         4
# 9625        11181                         1
# 9750        22999                         2
# 9875        93315                         5
#
#       Antigüedad del desarrollador (años) Idioma de programación Plataforma  \
# 0                                      10                   Java     Mobile
# 125                                     3             Javascript        Web
# 250                                    10                 Kotlin     Mobile
# 375                                     2                   Java        Web
# 500                                    12                 Python        Web
# ...                                   ...                    ...        ...
# 9375                                    2                 Kotlin        Web
# 9500                                    3                 Python    Desktop
# 9625                                    1                 Python        Web
# 9750                                   10                 Kotlin        Web
# 9875                                    4                   Java     Mobile
#
#        Tipo de proyecto Fase del proyecto  Tamaño del equipo  \
# 0           Application        Deployment                  7
# 125   Management System       Development                  4
# 250         Application        Deployment                  9
# 375         Application        Deployment                 10
# 500         Application       Development                  2
# ...                 ...               ...                ...
# 9375        Application            Design                  6
# 9500  Management System       Development                  2
# 9625  Management System           Testing                  9
# 9750           Web site            Design                  7
# 9875           Web site       Development                  8
#
#                       Tecnologías
# 0       professor, evidence, down
# 125              idea, arm, place
# 250          any, strong, clearly
# 375          center, mouth, share
# 500          assume, after, there
# ...                           ...
# 9375            go, early, course
# 9500     soon, operation, outside
# 9625    anything, ahead, painting
# 9750        either, fast, general
# 9875  represent, explain, himself
#
# [80 rows x 15 columns]

# %% [markdown]
# #Analisis de subpoblacion
#
# ---

# %% [markdown]
# ##Dividir la poblacion por tipo de proyecto
#
# ---

# %%
grouped_by_project_type = data.groupby('Tipo de proyecto')

# %% [markdown]
# ##Calcular el promedio de lineas de codigo y bugs para cada subpoblacion
#
# ---

# %%
group_analysis = grouped_by_project_type[['Número de bugs','Satisfacción del cliente']].mean()
print("Analisis de subpoblacion: ")
display(group_analysis)
# Out:
# Analisis de subpoblacion:
#                    Número de bugs  Satisfacción del cliente
# Tipo de proyecto
# Application             25.308058                  3.011894
# Management System       25.029096                  2.966003
# Web site                24.800712                  3.025801
